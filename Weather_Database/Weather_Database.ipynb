# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
cityurl = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(cityurl)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e37727e40698795dda9c3b27877fd679

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities): 

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = cityurl + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})


# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | buin
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | rehoboth
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | bubaque
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | gat
# Processing Record 14 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | padang
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | andra
# Processing Record 23 of Set 1 | tenenkou
# Processing Record 24 of Set 1 | burnie
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | kashi
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | webuye
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | marsa matruh
# Processing Record 34 of Set 1 | qui nhon
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | lerwick
# Processing Record 43 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 1 | sibolga
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | port blair
# Processing Record 47 of Set 1 | tura
# Processing Record 48 of Set 1 | presidencia roque saenz pena
# Processing Record 49 of Set 1 | krasnoborsk
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | zhuhai
# Processing Record 2 of Set 2 | tshela
# Processing Record 3 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 2 | abreus
# Processing Record 5 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | rio gallegos
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | ahuimanu
# Processing Record 18 of Set 2 | alta floresta
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | tomatlan
# Processing Record 23 of Set 2 | luhacovice
# Processing Record 24 of Set 2 | hervey bay
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | jijiga
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | tokur
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 2 | port-cartier
# Processing Record 33 of Set 2 | shingu
# Processing Record 34 of Set 2 | lodja
# Processing Record 35 of Set 2 | kirakira
# Processing Record 36 of Set 2 | awjilah
# Processing Record 37 of Set 2 | salalah
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | tabuk
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | saint-francois
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | krasnyy yar
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | bagua grande
# Processing Record 1 of Set 3 | port lincoln
# Processing Record 2 of Set 3 | murgab
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | ust-koksa
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | srednekolymsk
# Processing Record 7 of Set 3 | san cristobal
# Processing Record 8 of Set 3 | dubbo
# Processing Record 9 of Set 3 | beringovskiy
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | rawson
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | palmer
# Processing Record 14 of Set 3 | taldan
# Processing Record 15 of Set 3 | hokitika
# Processing Record 16 of Set 3 | gizo
# Processing Record 17 of Set 3 | comodoro rivadavia
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | chifeng
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | caravelas
# Processing Record 22 of Set 3 | eyl
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | balkhash
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 3 | ihosy
# Processing Record 28 of Set 3 | ossora
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | tongren
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | katobu
# Processing Record 39 of Set 3 | ketchikan
# Processing Record 40 of Set 3 | jiayuguan
# Processing Record 41 of Set 3 | riyadh
# Processing Record 42 of Set 3 | poya
# Processing Record 43 of Set 3 | linjiang
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 3 | samarai
# Processing Record 47 of Set 3 | raga
# Processing Record 48 of Set 3 | yithion
# City not found. Skipping...
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | jiangyou
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | takoradi
# Processing Record 4 of Set 4 | wuwei
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | fort nelson
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | walvis bay
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | la ronge
# Processing Record 13 of Set 4 | cururupu
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | appingedam
# Processing Record 16 of Set 4 | rio pomba
# Processing Record 17 of Set 4 | san luis
# Processing Record 18 of Set 4 | meadow lake
# Processing Record 19 of Set 4 | wagar
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | harper
# Processing Record 22 of Set 4 | fountain
# Processing Record 23 of Set 4 | klaksvik
# Processing Record 24 of Set 4 | calama
# Processing Record 25 of Set 4 | rokosovo
# Processing Record 26 of Set 4 | vaitape
# Processing Record 27 of Set 4 | caconda
# Processing Record 28 of Set 4 | dakar
# Processing Record 29 of Set 4 | waingapu
# Processing Record 30 of Set 4 | buta
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | ayan
# Processing Record 33 of Set 4 | abnub
# Processing Record 34 of Set 4 | saint-philippe
# Processing Record 35 of Set 4 | goderich
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | linxia
# Processing Record 38 of Set 4 | higuey
# City not found. Skipping...
# Processing Record 39 of Set 4 | yarada
# Processing Record 40 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 41 of Set 4 | povenets
# Processing Record 42 of Set 4 | lasa
# Processing Record 43 of Set 4 | waipawa
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | baoro
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | miri
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | corinto
# Processing Record 3 of Set 5 | duayaw nkwanta
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | praia da vitoria
# Processing Record 6 of Set 5 | bathurst
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | formosa
# Processing Record 9 of Set 5 | puerto el triunfo
# Processing Record 10 of Set 5 | cintalapa
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | westport
# Processing Record 13 of Set 5 | matay
# Processing Record 14 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | hvide sande
# Processing Record 17 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 5 | ridgecrest
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | spring hill
# Processing Record 21 of Set 5 | maniitsoq
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | eregli
# Processing Record 24 of Set 5 | luang prabang
# Processing Record 25 of Set 5 | nantucket
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 5 | kharian
# Processing Record 29 of Set 5 | hualmay
# Processing Record 30 of Set 5 | novobirilyussy
# Processing Record 31 of Set 5 | tabas
# Processing Record 32 of Set 5 | anadyr
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | mahebourg
# Processing Record 35 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 36 of Set 5 | honiara
# Processing Record 37 of Set 5 | yumen
# Processing Record 38 of Set 5 | santa rosa
# Processing Record 39 of Set 5 | bay roberts
# Processing Record 40 of Set 5 | angoche
# Processing Record 41 of Set 5 | tornio
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | nikolskoye
# Processing Record 44 of Set 5 | college
# Processing Record 45 of Set 5 | sur
# Processing Record 46 of Set 5 | boulder
# Processing Record 47 of Set 5 | chumikan
# Processing Record 48 of Set 5 | port macquarie
# Processing Record 49 of Set 5 | karpuninskiy
# City not found. Skipping...
# Processing Record 50 of Set 5 | lensk
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | itarema
# Processing Record 3 of Set 6 | pedernales
# Processing Record 4 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | mount gambier
# Processing Record 7 of Set 6 | namatanai
# Processing Record 8 of Set 6 | bagdarin
# Processing Record 9 of Set 6 | chernyshevskiy
# Processing Record 10 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 6 | fomboni
# Processing Record 12 of Set 6 | kyrylivka
# Processing Record 13 of Set 6 | oistins
# Processing Record 14 of Set 6 | kamaishi
# Processing Record 15 of Set 6 | lastoursville
# Processing Record 16 of Set 6 | nova odesa
# Processing Record 17 of Set 6 | margate
# Processing Record 18 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 6 | camalu
# Processing Record 20 of Set 6 | birao
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | sinaloa
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | samarkand
# Processing Record 25 of Set 6 | anshun
# Processing Record 26 of Set 6 | narsaq
# Processing Record 27 of Set 6 | jiquilisco
# Processing Record 28 of Set 6 | edwardsville
# Processing Record 29 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | tazovskiy
# Processing Record 33 of Set 6 | swellendam
# Processing Record 34 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 35 of Set 6 | dundee
# Processing Record 36 of Set 6 | fukue
# Processing Record 37 of Set 6 | bagado
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | balikpapan
# Processing Record 40 of Set 6 | ulladulla
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | muisne
# Processing Record 43 of Set 6 | gora kalwaria
# Processing Record 44 of Set 6 | amuntai
# Processing Record 45 of Set 6 | quatre cocos
# Processing Record 46 of Set 6 | segezha
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | patacamaya
# Processing Record 49 of Set 6 | yeppoon
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | ushtobe
# Processing Record 2 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 7 | soria
# Processing Record 4 of Set 7 | port hardy
# Processing Record 5 of Set 7 | bengkulu
# Processing Record 6 of Set 7 | puerto baquerizo moreno
# Processing Record 7 of Set 7 | el sauzal
# Processing Record 8 of Set 7 | ornes
# Processing Record 9 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 7 | boende
# Processing Record 11 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | joshimath
# Processing Record 14 of Set 7 | bairiki
# Processing Record 15 of Set 7 | bandarbeyla
# Processing Record 16 of Set 7 | general roca
# Processing Record 17 of Set 7 | tautira
# Processing Record 18 of Set 7 | grants
# Processing Record 19 of Set 7 | sovetskiy
# Processing Record 20 of Set 7 | mairi
# Processing Record 21 of Set 7 | nhulunbuy
# Processing Record 22 of Set 7 | pangai
# Processing Record 23 of Set 7 | paranhos
# Processing Record 24 of Set 7 | ustyuzhna
# Processing Record 25 of Set 7 | chicama
# Processing Record 26 of Set 7 | muli
# Processing Record 27 of Set 7 | barranca
# Processing Record 28 of Set 7 | ponta delgada
# Processing Record 29 of Set 7 | inhambane
# Processing Record 30 of Set 7 | ogaminana
# Processing Record 31 of Set 7 | kindu
# Processing Record 32 of Set 7 | stykkisholmur
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | rosetta
# Processing Record 35 of Set 7 | shaunavon
# Processing Record 36 of Set 7 | gigmoto
# Processing Record 37 of Set 7 | bardiyah
# Processing Record 38 of Set 7 | teya
# Processing Record 39 of Set 7 | jalu
# Processing Record 40 of Set 7 | camacha
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | helena
# Processing Record 43 of Set 7 | lincoln
# Processing Record 44 of Set 7 | moshenskoye
# Processing Record 45 of Set 7 | rocha
# Processing Record 46 of Set 7 | saldanha
# Processing Record 47 of Set 7 | kattivakkam
# Processing Record 48 of Set 7 | bonaventure
# Processing Record 49 of Set 7 | broome
# Processing Record 50 of Set 7 | nangomba
# Processing Record 1 of Set 8 | san jose
# Processing Record 2 of Set 8 | hambantota
# Processing Record 3 of Set 8 | atlantic city
# Processing Record 4 of Set 8 | polovinnoye
# Processing Record 5 of Set 8 | mercedes
# Processing Record 6 of Set 8 | buluang
# Processing Record 7 of Set 8 | wajima
# Processing Record 8 of Set 8 | aleksandrov gay
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | tashtyp
# Processing Record 11 of Set 8 | teguise
# Processing Record 12 of Set 8 | kurchum
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | alto araguaia
# Processing Record 15 of Set 8 | carutapera
# Processing Record 16 of Set 8 | challapata
# Processing Record 17 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 8 | pirgos
# Processing Record 19 of Set 8 | gravdal
# Processing Record 20 of Set 8 | dzaoudzi
# Processing Record 21 of Set 8 | maharajganj
# Processing Record 22 of Set 8 | warrington
# Processing Record 23 of Set 8 | rumonge
# Processing Record 24 of Set 8 | nishihara
# Processing Record 25 of Set 8 | axim
# Processing Record 26 of Set 8 | huarmey
# Processing Record 27 of Set 8 | mount isa
# Processing Record 28 of Set 8 | conde
# Processing Record 29 of Set 8 | poronaysk
# Processing Record 30 of Set 8 | dunedin
# Processing Record 31 of Set 8 | ploemeur
# Processing Record 32 of Set 8 | esmeraldas
# Processing Record 33 of Set 8 | noyabrsk
# Processing Record 34 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 35 of Set 8 | mabaruma
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | alofi
# Processing Record 38 of Set 8 | banda aceh
# Processing Record 39 of Set 8 | gandu
# Processing Record 40 of Set 8 | fayetteville
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | da nang
# Processing Record 43 of Set 8 | riberalta
# Processing Record 44 of Set 8 | icod de los vinos
# Processing Record 45 of Set 8 | faanui
# Processing Record 46 of Set 8 | tranas
# Processing Record 47 of Set 8 | atasu
# Processing Record 48 of Set 8 | qianguo
# Processing Record 49 of Set 8 | kalabo
# Processing Record 50 of Set 8 | nabire
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | panguna
# Processing Record 3 of Set 9 | kota belud
# Processing Record 4 of Set 9 | cabedelo
# Processing Record 5 of Set 9 | moose factory
# Processing Record 6 of Set 9 | lompoc
# Processing Record 7 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 9 | zakharovo
# Processing Record 9 of Set 9 | pimenta bueno
# Processing Record 10 of Set 9 | palaikastron
# Processing Record 11 of Set 9 | chiredzi
# Processing Record 12 of Set 9 | xunchang
# Processing Record 13 of Set 9 | gasa
# Processing Record 14 of Set 9 | swan river
# Processing Record 15 of Set 9 | esil
# Processing Record 16 of Set 9 | vila velha
# Processing Record 17 of Set 9 | yining
# Processing Record 18 of Set 9 | la rochelle
# Processing Record 19 of Set 9 | naze
# Processing Record 20 of Set 9 | lardos
# Processing Record 21 of Set 9 | korem
# Processing Record 22 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 9 | pontianak
# Processing Record 25 of Set 9 | tual
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | willowmore
# Processing Record 28 of Set 9 | palembang
# Processing Record 29 of Set 9 | rouvroy
# Processing Record 30 of Set 9 | tucuma
# Processing Record 31 of Set 9 | taoudenni
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | veisiejai
# Processing Record 34 of Set 9 | tessalit
# Processing Record 35 of Set 9 | alcains
# Processing Record 36 of Set 9 | maxixe
# Processing Record 37 of Set 9 | huilong
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | kholm-zhirkovskiy
# Processing Record 40 of Set 9 | ambilobe
# Processing Record 41 of Set 9 | olinda
# Processing Record 42 of Set 9 | sillamae
# Processing Record 43 of Set 9 | yuancheng
# Processing Record 44 of Set 9 | biloela
# Processing Record 45 of Set 9 | souillac
# Processing Record 46 of Set 9 | juneau
# Processing Record 47 of Set 9 | talcahuano
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | manokwari
# Processing Record 50 of Set 9 | altay
# Processing Record 1 of Set 10 | guaymas
# Processing Record 2 of Set 10 | saint-georges
# Processing Record 3 of Set 10 | sabang
# Processing Record 4 of Set 10 | prince albert
# Processing Record 5 of Set 10 | trincomalee
# Processing Record 6 of Set 10 | robertson
# Processing Record 7 of Set 10 | varhaug
# Processing Record 8 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | grand gaube
# Processing Record 11 of Set 10 | marystown
# Processing Record 12 of Set 10 | santa cruz
# Processing Record 13 of Set 10 | tekeli
# Processing Record 14 of Set 10 | tromso
# Processing Record 15 of Set 10 | tuatapere
# Processing Record 16 of Set 10 | guerrero negro
# Processing Record 17 of Set 10 | oussouye
# Processing Record 18 of Set 10 | opuwo
# Processing Record 19 of Set 10 | yangjiang
# Processing Record 20 of Set 10 | baykit
# Processing Record 21 of Set 10 | mirnyy
# Processing Record 22 of Set 10 | balykshi
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 10 | hamilton
# Processing Record 26 of Set 10 | ust-kuyga
# Processing Record 27 of Set 10 | santa isabel
# Processing Record 28 of Set 10 | marshall
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | maragogi
# Processing Record 31 of Set 10 | quang ngai
# Processing Record 32 of Set 10 | macherla
# Processing Record 33 of Set 10 | buraydah
# Processing Record 34 of Set 10 | rio grande
# Processing Record 35 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 10 | jumla
# Processing Record 37 of Set 10 | sola
# Processing Record 38 of Set 10 | nara
# Processing Record 39 of Set 10 | bure
# Processing Record 40 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 10 | braslav
# City not found. Skipping...
# Processing Record 42 of Set 10 | llangefni
# Processing Record 43 of Set 10 | rognan
# Processing Record 44 of Set 10 | trairi
# Processing Record 45 of Set 10 | iralaya
# Processing Record 46 of Set 10 | verkhoyansk
# Processing Record 47 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 10 | tulun
# Processing Record 49 of Set 10 | san policarpo
# Processing Record 50 of Set 10 | rock springs
# Processing Record 1 of Set 11 | necochea
# Processing Record 2 of Set 11 | bang saphan
# Processing Record 3 of Set 11 | hami
# Processing Record 4 of Set 11 | maues
# Processing Record 5 of Set 11 | saint george
# Processing Record 6 of Set 11 | grand-bourg
# Processing Record 7 of Set 11 | alugan
# Processing Record 8 of Set 11 | babynino
# Processing Record 9 of Set 11 | richards bay
# Processing Record 10 of Set 11 | matameye
# City not found. Skipping...
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | dali
# Processing Record 13 of Set 11 | port-gentil
# Processing Record 14 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 11 | songjianghe
# Processing Record 16 of Set 11 | gweta
# Processing Record 17 of Set 11 | acapulco
# Processing Record 18 of Set 11 | lorengau
# Processing Record 19 of Set 11 | kosh-agach
# Processing Record 20 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 11 | vila franca do campo
# Processing Record 22 of Set 11 | rantauprapat
# Processing Record 23 of Set 11 | mizdah
# Processing Record 24 of Set 11 | kuantan
# Processing Record 25 of Set 11 | bjornevatn
# Processing Record 26 of Set 11 | miyako
# Processing Record 27 of Set 11 | munster
# Processing Record 28 of Set 11 | jos
# Processing Record 29 of Set 11 | lapua
# Processing Record 30 of Set 11 | sumbe
# Processing Record 31 of Set 11 | bam
# Processing Record 32 of Set 11 | ixtapa
# Processing Record 33 of Set 11 | andros
# Processing Record 34 of Set 11 | shelburne
# Processing Record 35 of Set 11 | merauke
# Processing Record 36 of Set 11 | buckeye
# Processing Record 37 of Set 11 | vardo
# Processing Record 38 of Set 11 | ternate
# Processing Record 39 of Set 11 | duz
# City not found. Skipping...
# Processing Record 40 of Set 11 | huntington
# Processing Record 41 of Set 11 | batemans bay
# Processing Record 42 of Set 11 | adela
# Processing Record 43 of Set 11 | gillette
# Processing Record 44 of Set 11 | jennings
# Processing Record 45 of Set 11 | tiznit
# Processing Record 46 of Set 11 | egvekinot
# Processing Record 47 of Set 11 | sapao
# City not found. Skipping...
# Processing Record 48 of Set 11 | maltahohe
# Processing Record 49 of Set 11 | kahului
# Processing Record 50 of Set 11 | gari
# Processing Record 1 of Set 12 | nova olimpia
# Processing Record 2 of Set 12 | urengoy
# Processing Record 3 of Set 12 | bharatpur
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | zabaykalsk
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | zheleznodorozhnyy
# Processing Record 9 of Set 12 | lata
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | loandjili
# Processing Record 13 of Set 12 | madisonville
# Processing Record 14 of Set 12 | kigonsera
# Processing Record 15 of Set 12 | zeya
# Processing Record 16 of Set 12 | colares
# Processing Record 17 of Set 12 | kokkola
# Processing Record 18 of Set 12 | grand-santi
# Processing Record 19 of Set 12 | udachnyy
# Processing Record 20 of Set 12 | sesheke
# Processing Record 21 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | mumford
# Processing Record 24 of Set 12 | manggar
# Processing Record 25 of Set 12 | maldonado
# Processing Record 26 of Set 12 | nepomuceno
# Processing Record 27 of Set 12 | pauini
# Processing Record 28 of Set 12 | garowe
# Processing Record 29 of Set 12 | kurduvadi
# Processing Record 30 of Set 12 | tahe
# Processing Record 31 of Set 12 | pinyug
# Processing Record 32 of Set 12 | anapskaya
# Processing Record 33 of Set 12 | taksimo
# Processing Record 34 of Set 12 | marawi
# Processing Record 35 of Set 12 | luba
# Processing Record 36 of Set 12 | berdigestyakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Rikitea -23.12 -134.97     76.95        73          74        7.11
# 1            Buin -33.73  -70.75     68.00        42          31        6.93
# 2       Busselton -33.65  115.33     72.00        35           0        1.99
# 3          Dikson  73.51   80.55    -19.79        88          74        9.26
# 4        Rehoboth -23.32   17.08     57.65        35           9        3.49
# 5     New Norfolk -42.78  147.06     77.00        68          40       26.40
# 6         Bubaque  11.28  -15.83     79.29        60           4       15.68
# 7  Cabo San Lucas  22.89 -109.91     66.00        72           5       13.87
# 8      Nanortalik  60.14  -45.24     32.95        91         100        3.31
# 9        Victoria  22.29  114.16     61.00        72          52        1.99
#
#   Country                 Date
# 0      PF  2020-12-15 03:46:01
# 1      CL  2020-12-15 03:46:03
# 2      AU  2020-12-15 03:46:03
# 3      RU  2020-12-15 03:42:08
# 4      NA  2020-12-15 03:46:03
# 5      AU  2020-12-15 03:46:04
# 6      GW  2020-12-15 03:46:04
# 7      MX  2020-12-15 03:42:16
# 8      GL  2020-12-15 03:42:08
# 9      HK  2020-12-15 03:43:24

# %%
print (city_data)
# Out:
# [{'City': 'Rikitea', 'Lat': -23.12, 'Lng': -134.97, 'Max Temp': 76.95, 'Humidity': 73, 'Cloudiness': 74, 'Wind Speed': 7.11, 'Country': 'PF', 'Date': '2020-12-15 03:46:01'}, {'City': 'Buin', 'Lat': -33.73, 'Lng': -70.75, 'Max Temp': 68, 'Humidity': 42, 'Cloudiness': 31, 'Wind Speed': 6.93, 'Country': 'CL', 'Date': '2020-12-15 03:46:03'}, {'City': 'Busselton', 'Lat': -33.65, 'Lng': 115.33, 'Max Temp': 72, 'Humidity': 35, 'Cloudiness': 0, 'Wind Speed': 1.99, 'Country': 'AU', 'Date': '2020-12-15 03:46:03'}, {'City': 'Dikson', 'Lat': 73.51, 'Lng': 80.55, 'Max Temp': -19.79, 'Humidity': 88, 'Cloudiness': 74, 'Wind Speed': 9.26, 'Country': 'RU', 'Date': '2020-12-15 03:42:08'}, {'City': 'Rehoboth', 'Lat': -23.32, 'Lng': 17.08, 'Max Temp': 57.65, 'Humidity': 35, 'Cloudiness': 9, 'Wind Speed': 3.49, 'Country': 'NA', 'Date': '2020-12-15 03:46:03'}, {'City': 'New Norfolk', 'Lat': -42.78, 'Lng': 147.06, 'Max Temp': 77, 'Humidity': 68, 'Cloudiness': 40, 'Wind Speed': 26.4, 'Country': 'AU', 'Date': '2020-12-15 03:46:04'}, {'City': 'Bubaque', 'Lat': 11.28, 'Lng': -15.83, 'Max Temp': 79.29, 'Humidity': 60, 'Cloudiness': 4, 'Wind Speed': 15.68, 'Country': 'GW', 'Date': '2020-12-15 03:46:04'}, {'City': 'Cabo San Lucas', 'Lat': 22.89, 'Lng': -109.91, 'Max Temp': 66, 'Humidity': 72, 'Cloudiness': 5, 'Wind Speed': 13.87, 'Country': 'MX', 'Date': '2020-12-15 03:42:16'}, {'City': 'Nanortalik', 'Lat': 60.14, 'Lng': -45.24, 'Max Temp': 32.95, 'Humidity': 91, 'Cloudiness': 100, 'Wind Speed': 3.31, 'Country': 'GL', 'Date': '2020-12-15 03:42:08'}, {'City': 'Victoria', 'Lat': 22.29, 'Lng': 114.16, 'Max Temp': 61, 'Humidity': 72, 'Cloudiness': 52, 'Wind Speed': 1.99, 'Country': 'HK', 'Date': '2020-12-15 03:43:24'}, {'City': 'Gat', 'Lat': 31.61, 'Lng': 34.76, 'Max Temp': 57, 'Humidity': 38, 'Cloudiness': 0, 'Wind Speed': 1.01, 'Country': 'IL', 'Date': '2020-12-15 03:46:04'}, {'City': 'Bluff', 'Lat': -46.6, 'Lng': 168.33, 'Max Temp': 63, 'Humidity': 71, 'Cloudiness': 0, 'Wind Speed': 14, 'Country': 'NZ', 'Date': '2020-12-15 03:46:04'}, {'City': 'Carnarvon', 'Lat': -24.87, 'Lng': 113.63, 'Max Temp': 78.8, 'Humidity': 57, 'Cloudiness': 0, 'Wind Speed': 19.46, 'Country': 'AU', 'Date': '2020-12-15 03:46:05'}, {'City': 'Mataura', 'Lat': -46.19, 'Lng': 168.86, 'Max Temp': 63, 'Humidity': 71, 'Cloudiness': 0, 'Wind Speed': 14, 'Country': 'NZ', 'Date': '2020-12-15 03:46:05'}, {'City': 'Provideniya', 'Lat': 64.38, 'Lng': -173.3, 'Max Temp': 17.6, 'Humidity': 72, 'Cloudiness': 90, 'Wind Speed': 20.13, 'Country': 'RU', 'Date': '2020-12-15 03:46:05'}, {'City': 'Port Alfred', 'Lat': -33.59, 'Lng': 26.89, 'Max Temp': 66, 'Humidity': 94, 'Cloudiness': 99, 'Wind Speed': 3, 'Country': 'ZA', 'Date': '2020-12-15 03:46:05'}, {'City': 'Padang', 'Lat': -0.95, 'Lng': 100.35, 'Max Temp': 84.43, 'Humidity': 62, 'Cloudiness': 100, 'Wind Speed': 4.76, 'Country': 'ID', 'Date': '2020-12-15 03:46:05'}, {'City': 'Ponta Do Sol', 'Lat': 32.67, 'Lng': -17.1, 'Max Temp': 60.8, 'Humidity': 59, 'Cloudiness': 20, 'Wind Speed': 8.05, 'Country': 'PT', 'Date': '2020-12-15 03:46:05'}, {'City': 'Andra', 'Lat': 62.51, 'Lng': 65.89, 'Max Temp': 0.5, 'Humidity': 92, 'Cloudiness': 15, 'Wind Speed': 4, 'Country': 'RU', 'Date': '2020-12-15 03:46:05'}, {'City': 'Tenenkou', 'Lat': 14.46, 'Lng': -4.92, 'Max Temp': 71.2, 'Humidity': 23, 'Cloudiness': 26, 'Wind Speed': 9.75, 'Country': 'ML', 'Date': '2020-12-15 03:46:05'}, {'City': 'Burnie', 'Lat': -41.07, 'Lng': 145.92, 'Max Temp': 77, 'Humidity': 70, 'Cloudiness': 6, 'Wind Speed': 13, 'Country': 'AU', 'Date': '2020-12-15 03:46:06'}, {'City': 'Arraial Do Cabo', 'Lat': -22.97, 'Lng': -42.03, 'Max Temp': 73.4, 'Humidity': 89, 'Cloudiness': 40, 'Wind Speed': 12.75, 'Country': 'BR', 'Date': '2020-12-15 03:46:06'}, {'City': 'Albany', 'Lat': 42.6, 'Lng': -73.97, 'Max Temp': 34, 'Humidity': 70, 'Cloudiness': 31, 'Wind Speed': 1.99, 'Country': 'US', 'Date': '2020-12-15 03:45:28'}, {'City': 'Kashi', 'Lat': 39.45, 'Lng': 75.98, 'Max Temp': 24.8, 'Humidity': 92, 'Cloudin ...

# %%
city_data_df.to_csv("WeatherPy_database.csv")
